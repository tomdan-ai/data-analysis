# %%
# SECTION 1: Common Data Sources

common_data_sources = [
    {"S/N": 1, "Source": "CSV Files", "Descriptions": "Comma-separated values, often exported from Excel or databases"},
    {"S/N": 2, "Source": "Excel Files", "Descriptions": "XLS/XLSX format used in spreadsheets"},
    {"S/N": 3, "Source": "Databases", "Descriptions": "SQL (MySQL, PostgreSQL, SQLite), NoSQL (MongoDB)"},
    {"S/N": 4, "Source": "Web APIs", "Descriptions": "JSON/XML data from REST APIs"},
    {"S/N": 5, "Source": "Big Data Systems", "Descriptions": "HDFS, Apache Spark, AWS S3"},
    {"S/N": 6, "Source": "HTML Tables", "Descriptions": "Extracted from web pages via scraping"},
]

print("SECTION 1: Common Data Sources\n")
for item in common_data_sources:
    print(f"{item['S/N']}. Source: {item['Source']}")
    print(f"   Description: {item['Descriptions']}\n")


# SECTION 2: Common Data Formats

common_data_formats = [
    {"S/N": 1, "FORMAT": ".csv", "TOOL/METHOD": "pd.read_csv()", "NOTES": "Most common flat file"},
    {"S/N": 2, "FORMAT": ".xlsx", "TOOL/METHOD": "pd.read_excel()", "NOTES": "Needs openpyxl or xlrd"},
    {"S/N": 3, "FORMAT": ".json", "TOOL/METHOD": "pd.read_json()", "NOTES": "Hierarchical, human-readable"},
    {"S/N": 4, "FORMAT": ".sql", "TOOL/METHOD": "pd.read_sql()", "NOTES": "Via database connectors"},
    {"S/N": 5, "FORMAT": ".html", "TOOL/METHOD": "pd.read_html()", "NOTES": "Parses <table> tags"},
    {"S/N": 6, "FORMAT": ".parquet", "TOOL/METHOD": "pd.read_parquet()", "NOTES": "Efficient for large data (columnar storage)"},
]

print("SECTION 2: Common Data Formats\n")
for item in common_data_formats:
    print(f"{item['S/N']}. Format: {item['FORMAT']}")
    print(f"   Tool/Method: {item['TOOL/METHOD']}")
    print(f"   Notes: {item['NOTES']}\n")
# Out:
# SECTION 1: Common Data Sources
#
# 1. Source: CSV Files
#    Description: Comma-separated values, often exported from Excel or databases
#
# 2. Source: Excel Files
#    Description: XLS/XLSX format used in spreadsheets
#
# 3. Source: Databases
#    Description: SQL (MySQL, PostgreSQL, SQLite), NoSQL (MongoDB)
#
# 4. Source: Web APIs
#    Description: JSON/XML data from REST APIs
#
# 5. Source: Big Data Systems
#    Description: HDFS, Apache Spark, AWS S3
#
# 6. Source: HTML Tables
#    Description: Extracted from web pages via scraping
#
# SECTION 2: Common Data Formats
#
# 1. Format: .csv
#    Tool/Method: pd.read_csv()
#    Notes: Most common flat file
#
# 2. Format: .xlsx
#    Tool/Method: pd.read_excel()
#    Notes: Needs openpyxl or xlrd
#
# 3. Format: .json
#    Tool/Method: pd.read_json()
#    Notes: Hierarchical, human-readable
#
# 4. Format: .sql
#    Tool/Method: pd.read_sql()
#    Notes: Via database connectors
#
# 5. Format: .html
#    Tool/Method: pd.read_html()
#    Notes: Parses <table> tags
#
# 6. Format: .parquet
#    Tool/Method: pd.read_parquet()
#    Notes: Efficient for large data (columnar storage)
